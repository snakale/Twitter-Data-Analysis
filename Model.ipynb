# %% [markdown]
# # Imports
# All the imports needed for our project

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
from os import listdir
from os.path import isfile, join
from random import shuffle
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
import numpy as np # linear algebra
from joblib import dump, load # used for saving and loading sklearn objects
from scipy.sparse import save_npz, load_npz # used for saving and loading sparse matrices
from scipy.stats import uniform
from scipy.sparse import csr_matrix
from functools import reduce

# %% [markdown]
# ##1.2 Import from our code

# %%
from extract_dataframe import read_json
from extract_dataframe import extract_data_file
from extract_dataframe import TweetDfExtractor
from extract_dataframe import path_to_file
from clean_tweets_dataframe import Clean_Tweets

# %%
#extract data file if not yet extracted
extract_data_file()

# %% [markdown]
# # 2. Extract DataFrame

# %%
_, tweet_list = read_json("./data/Economic_Twitter_Data.json")
tweet = TweetDfExtractor(tweet_list)
tweet_df = tweet.get_tweet_df(True)
# Out:
# File Successfully Saved.!!!

# %%
tweet_df.head(n=10)
# Out:
#                        created_at  \
# 0  Fri Apr 22 22:20:18 +0000 2022
# 1  Fri Apr 22 22:19:16 +0000 2022
# 2  Fri Apr 22 22:17:28 +0000 2022
# 3  Fri Apr 22 22:17:20 +0000 2022
# 4  Fri Apr 22 22:13:15 +0000 2022
# 5  Fri Apr 22 22:12:51 +0000 2022
# 6  Fri Apr 22 22:12:17 +0000 2022
# 7  Fri Apr 22 22:10:01 +0000 2022
# 8  Fri Apr 22 22:09:38 +0000 2022
# 9  Fri Apr 22 22:04:16 +0000 2022
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="http://twitter.com/download/android" ...
# 6  <a href="http://twitter.com/download/android" ...
# 7  <a href="http://twitter.com/download/android" ...
# 8  <a href="http://twitter.com/download/android" ...
# 9  <a href="http://twitter.com/download/android" ...
#
#                                        original_text  polarity  subjectivity  \
# 0  RT @nikitheblogger: Irre: Annalena Baerbock sa...       0.0           0.0
# 1  RT @sagt_mit: Merkel schaffte es in 1 Jahr 1 M...       0.0           0.0
# 2  RT @Kryptonoun: @WRi007 Pharma in Lebensmittel...       0.0           0.0
# 3  RT @WRi007: Die #Deutschen sind ein braves Vol...       0.0           0.0
# 4  RT @RolandTichy: Baerbock verkündet mal so neb...       0.0           0.0
# 5           RT @biggyyyyyyy: https://t.co/jvvA7F9m4U       0.0           0.0
# 6  RT @SiriaBlack_II: Ich bin mir sicher, dass vi...       0.0           0.0
# 7  RT @Darling_2022: Ich wiederhole mich gerne no...       0.0           0.0
# 8  RT @rosenbusch_: Brigadegeneral a. D. Erich Va...       0.0           1.0
# 9  RT @kickout55711802: Klasse Rede über die Fern...       0.0           0.0
#
#   lang  favorite_count  retweet_count original_author  followers_count  \
# 0   de               0            355    McMc74078966                3
# 1   de               0            505    McMc74078966                3
# 2   de               0              4    McMc74078966                3
# 3   de               0            332    McMc74078966                3
# 4   de               0            386    McMc74078966                3
# 5  und               0             77    McMc74078966                3
# 6   de               0            129    McMc74078966                3
# 7   de               0            860    McMc74078966                3
# 8   de               0            926    McMc74078966                3
# 9   de               0            285    McMc74078966                3
#
#    friends_count possibly_sensitive  \
# 0             12               None
# 1             12               None
# 2             12               None
# 3             12               None
# 4             12               None
# 5             12              False
# 6             12               None
# 7             12               None
# 8             12               None
# 9             12              False
#
#                                        hashtags         user_mentions place
# 0                                                     @nikitheblogger
# 1                                                           @sagt_mit
# 2                                                @Kryptonoun, @WRi007
# 3  #Deutschen #Spritpreisen #inflation #Abgaben               @WRi007
# 4                                                        @RolandTichy
# 5                                                        @biggyyyyyyy
# 6                                     #Baerbock        @SiriaBlack_II
# 7                                                       @Darling_2022
# 8                                                        @rosenbusch_
# 9                                                    @kickout55711802

# %% [markdown]
# ## 3. Remove unwanted columns and irrelavant tweets

# %% [markdown]
# ## 3.1 drop duplicates

# %%
cleanTweetsWrapper = Clean_Tweets(tweet_df)
print('Length before dropping duplicates: ' + str(len(cleanTweetsWrapper.df)))
cleanTweetsWrapper.drop_duplicate()
print('Length after dropping duplicates: ' + str(len(cleanTweetsWrapper.df)))
# Out:
# Automation in Action...!!!
# Length before dropping duplicates: 24625
# Length after dropping duplicates: 22481

# %%
print(cleanTweetsWrapper.df.loc[0, "original_text"])
# Out:
# RT @nikitheblogger: Irre: Annalena Baerbock sagt, es bricht ihr das Herz, dass man nicht bedingungslos schwere Waffen liefert.
# Mir bricht e…

# %% [markdown]
# ### 3.2 Remove Non-English Tweets

# %%
# %%time
print('Length before removing non-English: ' + str(len(cleanTweetsWrapper.df)))
cleanTweetsWrapper.remove_non_english_tweets()
print('Length after removing non-English: ' + str(len(cleanTweetsWrapper.df)))
# Out:
# Length before removing non-English: 15180
# Length after removing non-English: 15180
# Wall time: 139 ms

# %%
cleanTweetsWrapper.df.head(n=2)
# Out:
#                         created_at  \
# 38  Fri Apr 22 22:17:05 +0000 2022
# 39  Fri Apr 22 13:44:53 +0000 2022
#
#                                                source  \
# 38  <a href="http://twitter.com/download/android" ...
# 39  <a href="http://twitter.com/download/android" ...
#
#                                         original_text  polarity  subjectivity  \
# 38  RT @NorthstarCharts: The 10-year yield is tell...      0.16         0.540
# 39  RT @MichaelAArouet: German 10y mortgage rate w...      0.15         0.175
#
#    lang  favorite_count  retweet_count  original_author  followers_count  \
# 38   en               0             43  davideiacovozzi               18
# 39   en               0             32  davideiacovozzi               18
#
#     friends_count possibly_sensitive               hashtags     user_mentions  \
# 38             55               None  #gold #silver #crypto  @NorthstarCharts
# 39             55               None                          @MichaelAArouet
#
#    place
# 38
# 39

# %% [markdown]
# # 4. Construct 'bag-of-words'
#
# We need to go from Tweet DataFrames to Tweet actual text and then to numeric values

# %%
texts = [text for text in cleanTweetsWrapper.df['original_text']]
words = [t.split() for t in texts]
print(words)
# Out:
# [['RT', '@NorthstarCharts:', 'The', '10-year', 'yield', 'is', 'telling', 'us', 'that', "there's", 'a', 'high', 'risk', 'of', 'something', "'breaking'", 'in', 'the', 'system', '#gold', '#silver', '#crypto', '#…'], ['RT', '@MichaelAArouet:', 'German', '10y', 'mortgage', 'rate', 'went', 'from', '0,8%', 'to', '2,50%', '👇', 'Can', 'you', 'hear', 'the', 'sound', 'of', 'German', 'real', 'estate', 'bubble', 'bursting?', 'https:…'], ['RT', '@goldseek:', 'When?', 'https://t.co/kO2FfHKaZg'], ['RT', '@charliebilello:', 'The', '30-year', 'mortgage', 'rate', 'in', 'the', 'US', 'rises', 'to', '5.11%,', 'its', 'highest', 'level', 'since', '2010.', 'Last', 'year', 'it', 'hit', 'an', 'all-time', 'low', 'of', '2…'], ['RT', '@biancoresearch:', 'Rates', 'rise', 'until', 'something', 'breaks', '…', 'is', 'anything', 'broken', 'yet?', 'https://t.co/brNJeK3WTb'], ['RT', '@LanceRoberts:', 'Buying', 'opportunities', 'like', 'this', 'only', 'occur', 'every', 'few', 'years.', '#bonds', 'https://t.co/cyTVKNXkZD'], ['RT', '@MacroAlf:', 'Welcome', 'to', 'September', '2018.', 'Bond', 'markets', 'testing', 'what', 'risk', 'assets', 'and', 'the', 'private', 'sector', 'can', 'handle.', 'Until', 'they', 'can’t', 'handle…'], ['RT', '@BotBenFranklin:', 'The', 'horse', 'thinks', 'one', 'thing,', 'and', 'he', 'that', 'saddles', 'him', 'another.'], ['RT', '@Galactic_Trader:', 'Global', 'growth', 'optimism', 'at', 'all', 'time', 'lows!', 'We', 'should', 'raise', 'rates', '8', 'to', '9', 'more', 'times', 'and', 'see', 'what', 'happens', '!!!', 'https://t.…'], ['RT', '@AndreasSteno:', 'This', 'is', 'the', 'most', 'important', 'chart', 'in', 'the', 'world', 'for', 'the', 'demand', 'outlook...', 'Demand', 'is', 'softening', 'even', 'before', 'the', 'Fed', 'really…'], ['RT', '@WallStreetSilv:', 'Annual', 'mortgage', 'payments', 'in', 'the', 'US', 'are', 'now', '35%', 'higher', 'than', 'at', 'the', 'peak', 'of', 'the', '2006', 'bubble…', 'https://t.co/trUIZC7o5u'], ['RT', '@AndreasSteno:', 'The', 'most', 'important', 'chart', 'in', 'global', 'macro', 'right', 'now!', '🙀', 'Mind', 'the', 'gap!', 'https://t.co/rz4T4qTWKV'], ['RT', '@AndreasSteno:', 'JAPANIFICATION', 'OF', 'YIELDS', 'GONE?', 'The', 'Japanification', 'thesis', 'actually', 'suggests', 'that', 'a', 'bit', 'of', 'life', 'will', 'be', 'blown', 'into', 'the', 'EUR…'], ['RT', '@Schuldensuehner:', "ECB's", 'Lagarde:', '#ECB', 'will', 'complete', 'asset', 'purchases', 'first,', 'hike', 'some', 'time', 'thereafter.', '"Some', 'time', 'after"', 'can', 'be', 'anytime', 'b…'], ['RT', '@LanceRoberts:', 'Another', 'reason', '#deflation', 'is', 'a', 'larger', 'problem', 'going', 'forward.', '#Inventories', 'have', 'been', 'ramping', 'up,', 'but', '#NewOrders', 'are', 'dropp…'], ['RT', '@MacroAlf:', '30-year', 'mortgage', 'rates', 'above', '5%,', 'highest', 'since', '2010.', 'The', 'Fed', 'wants', 'to', 'cool', 'down', 'demand,', 'and', 'slowing', 'down', 'the', 'housing', 'market…'], ['RT', '@LanceRoberts:', 'Good', 'example', 'why', '#deflation', 'is', 'coming.', 'Fitch', 'says', '#oil', 'prices', 'will', 'hover', 'near', '$100/bbl,', 'which', 'means', '#gas', 'and', '#energy', 'cos…'], ['RT', '@TaviCosta:', 'The', 'set', 'up', 'is', 'here.', 'If', 'silver', 'were', 'to', 'follow', 'other', 'commodities,', 'it', 'would', 'imply', 'a', 'massive', 'appreciation', 'from', 'current', 'levels.…'], ['RT', '@MacroAlf:', 'BREAKING!', '10-year', 'Treasury', 'yields', 'broke', 'another', 'imaginary', 'line', 'drawn', 'on', 'a', 'random', 'time', 'scale…', '…on', 'a', 'log', 'chart!', 'This', 'unequiv…'], ['RT', '@MacroAlf:', '250', 'years', 'of', 'productivity', 'growth', 'data.', 'The', 'post-WWII', 'pickup', 'seems', 'rather', 'a', 'one-off', 'episode,', 'while', 'long-term', 'productivity', 'tre…'], ['"There', 'are', 'only', 'nine', 'meals', 'between', 'mankind', 'and', 'anarchy."', '(#AlfredHenryLewis,', '1906)', 'https://t.co/8ZMSNEv114'], ['RT', '@JackPScott:', '10-year', 'yields', 'and', '"events"', 'Not', 'if,', 'when.', 'http ...

# %% [markdown]
# ## Now we need to flaten the list
# https://stackoverflow.com/questions/952914/how-to-make-a-flat-list-out-of-a-list-of-lists

# %%
wordList = reduce(lambda x, y: x+y, words)
print(wordList)
